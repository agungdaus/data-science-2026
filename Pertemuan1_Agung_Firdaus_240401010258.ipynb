# %% [markdown]
# <a href="https://colab.research.google.com/github/agungdaus/data-science-2026/blob/main/Pertemuan1_Agung_Firdaus_240401010258.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("hello, Data Science!")
print ("Selamat datang di mata kuliah Pengantar Data Science!")
# Out:
# hello, Data Science!

# %%
nama = "Mahasiswa Informatika"    #String
angkatan = 2024                   #integer
ipk =3.79                         #float
aktif = True                      #boolean

print (f"Nama : {nama}")
print (f"Angkatan : {angkatan}")
print (f"IPK : {ipk}")
print (f"Aktif : {aktif}")
# Out:
# Nama : Mahasiswa Informatika
# Angkatan : 2024
# IPK : 3.79
# Aktif : True

# %%
tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]
print("\nTools Data Science yang akan kita pelajari:")
for i, tool in enumerate(tools, 1):
  print(f" {i}. {tool}")
# Out:
# Tools Data Science yang akan kita pelajari:
#  1. Python
#  2. Google Colab
#  3. Jupyter Notebook
#  4. GitHub

# %%
def perkenalan(nama, prodi, angkatan):
  """Fungsi untuk menampilkan perkenalan mahasiswa."""
  return f"Hai! Saya {nama} dari {prodi}, angkatan {angkatan}."
hasil = perkenalan("Agung Firdaus", "Informatika", 2024)
print(hasil)
# Out:
# Hai! Saya Agung Firdaus dari Informatika, angkatan 2024.
